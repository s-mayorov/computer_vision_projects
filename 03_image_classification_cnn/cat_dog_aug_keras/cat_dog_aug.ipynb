# %% [markdown]
# Here we've got no predefined dataset, just bunch of cats and dogs photos in `data/images/` named like `catxxx.jpg` and `dogxxx.jpg` where xxx is number. Totally there are 3000 images divided evenly between cats and dogs. We'll use 1000 images for train and 500 for validation for each of this two classes. Dogs  will be labeled 1, cats 0.

# %%
from os import listdir
from os.path import isfile, join

datapath = "./data/images/"

file_names = [f for f in listdir(datapath) if isfile(join(datapath, f))]

print(len(file_names), " images loaded")
# Out:
# 3000  images loaded

# %%
# Out:
# 'cat.13.jpg'

# %%
import cv2
import numpy as np
import sys
import shutil

dog_count = 0
cat_count = 0
training_size = 1000
test_size = 500
total_size = training_size + test_size
training_images = []
training_labels = []
test_images = []
test_labels = []

size = 150 # all images will be 150x150
dog_dir_train = "./data/train/dogs/"
cat_dir_train = "./data/train/cats/"
dog_dir_test = "./data/test/dogs/"
cat_dir_test = "./data/test/cats/"

for directory in [dog_dir_train, dog_dir_test, cat_dir_test, cat_dir_train]:
    if os.path.exists(directory):
        shutil.rmtree(directory)
    os.makedirs(directory)

# %%
for i, file in enumerate(file_names):
    if file.startswith('dog'):
        dog_count += 1
        image = cv2.imread(datapath+file)
        image = cv2.resize(image, (size, size), interpolation=cv2.INTER_AREA)
        if dog_count <= training_size:
            training_images.append(image)
            training_labels.append(1)
            cv2.imwrite("{}dog{:03d}.jpg".format(dog_dir_train, dog_count), image)
        elif dog_count > training_size and dog_count <= total_size:
            test_images.append(image)
            test_labels.append(1)
            cv2.imwrite("{}dog{:03d}.jpg".format(dog_dir_test, dog_count), image)

    elif file.startswith('cat'):
        cat_count += 1
        image = cv2.imread(datapath+file)
        image = cv2.resize(image, (size, size), interpolation=cv2.INTER_AREA)
        if cat_count <= training_size:
            training_images.append(image)
            training_labels.append(0)
            cv2.imwrite("{}cat{:03d}.jpg".format(cat_dir_train, cat_count), image)
        elif cat_count > training_size and cat_count <= total_size:
            test_images.append(image)
            test_labels.append(0)
            cv2.imwrite("{}cat{:03d}.jpg".format(cat_dir_test, cat_count), image)

    if dog_count == total_size and cat_count == total_size:
        break

print("Test/train split completed")
# Out:
# Test/train split completed

# %%
y_train = np.array(training_labels)
y_train = y_train.reshape(y_train.shape[0], 1)

y_test = np.array(test_labels)
y_test = y_test.reshape(y_test.shape[0], 1)

x_train = np.array(training_images).astype('float32') / 255
x_test = np.array(test_images).astype('float32') / 255

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout

model = Sequential()
model.add(Conv2D(32, (3,3), input_shape=(size, size, 3), activation="relu"))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(32, (3,3), activation="relu"))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(64, (3,3), activation="relu"))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(rate=0.5))
model.add(Dense(1, activation="sigmoid"))

model.compile(optimizer='rmsprop', loss="binary_crossentropy", metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, batch_size=16, epochs=25, validation_data=(x_test, y_test), shuffle=True)
# Out:
# Train on 2000 samples, validate on 1000 samples
# Epoch 1/25
# 2000/2000 [==============================] - 38s 19ms/step - loss: 0.7035 - accuracy: 0.5330 - val_loss: 0.6806 - val_accuracy: 0.6300
# Epoch 2/25
# 2000/2000 [==============================] - 40s 20ms/step - loss: 0.6690 - accuracy: 0.6135 - val_loss: 0.6320 - val_accuracy: 0.6640
# Epoch 3/25
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.6066 - accuracy: 0.6895 - val_loss: 0.6748 - val_accuracy: 0.5850
# Epoch 4/25
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.5609 - accuracy: 0.7290 - val_loss: 0.5940 - val_accuracy: 0.6780
# Epoch 5/25
# 2000/2000 [==============================] - 40s 20ms/step - loss: 0.5133 - accuracy: 0.7545 - val_loss: 0.6024 - val_accuracy: 0.7100
# Epoch 6/25
# 2000/2000 [==============================] - 40s 20ms/step - loss: 0.4512 - accuracy: 0.7945 - val_loss: 0.7190 - val_accuracy: 0.6690
# Epoch 7/25
# 2000/2000 [==============================] - 40s 20ms/step - loss: 0.4173 - accuracy: 0.8140 - val_loss: 0.7571 - val_accuracy: 0.6840
# Epoch 8/25
# 2000/2000 [==============================] - 40s 20ms/step - loss: 0.3644 - accuracy: 0.8500 - val_loss: 0.6537 - val_accuracy: 0.7310
# Epoch 9/25
# 2000/2000 [==============================] - 41s 20ms/step - loss: 0.3175 - accuracy: 0.8655 - val_loss: 0.7017 - val_accuracy: 0.7110
# Epoch 10/25
# 2000/2000 [==============================] - 40s 20ms/step - loss: 0.2715 - accuracy: 0.8885 - val_loss: 0.9046 - val_accuracy: 0.6990
# Epoch 11/25
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.2443 - accuracy: 0.9000 - val_loss: 0.9175 - val_accuracy: 0.7040
# Epoch 12/25
# 2000/2000 [==============================] - 40s 20ms/step - loss: 0.1943 - accuracy: 0.9215 - val_loss: 1.0766 - val_accuracy: 0.6940
# Epoch 13/25
# 2000/2000 [==============================] - 40s 20ms/step - loss: 0.1725 - accuracy: 0.9300 - val_loss: 1.1807 - val_accuracy: 0.6970
# Epoch 14/25
# 2000/2000 [==============================] - 40s 20ms/step - loss: 0.1565 - accuracy: 0.9415 - val_loss: 1.1729 - val_accuracy: 0.6900
# Epoch 15/25
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.1336 - accuracy: 0.9535 - val_loss: 1.3309 - val_accuracy: 0.6840
# Epoch 16/25
# 2000/2000 [==============================] - 40s 20ms/step - loss: 0.1192 - accuracy: 0.9620 - val_loss: 1.3782 - val_accuracy: 0.6890
# Epoch 17/25
# 2000/2000 [==============================] - 40s 20ms/step - loss: 0.1107 - accuracy: 0.9605 - val_loss: 1.5357 - val_accuracy: 0.7070
# Epoch 18/25
# 2000/2000 [==============================] - 40s 20ms/step - loss: 0.1165 - accuracy: 0.9630 - val_loss: 1.5232 - val_accuracy: 0.6940
# Epoch 19/25
# 2000/2000 [==============================] - 40s 20ms/step - loss: 0.0972 - accuracy: 0.9665 - val_loss: 1.4795 - val_accuracy: 0.6950
# Epoch 20/25
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.0703 - accuracy: 0.9770 - val_loss: 1.9226 - val_accuracy: 0.7010
# Epoch 21/25
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.1148 - accuracy: 0.9660 - val_loss: 2.0028 - val_accuracy: 0.6980
# Epoch 22/25
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.0815 - accuracy: 0.9725 - val_loss: 2.3643 - val_accuracy: 0.6940
# Epoch 23/25
# 2000/2000 [==============================] - 41s 21ms/step - loss: 0.0950 - accuracy: 0.9695 - val_loss: 2.1150 - val_accuracy: 0.7000
# Epoch 24/25
# 2000/2000 [==============================] - 42s 21ms/step - loss: 0.1140 - accuracy: 0.9660 - val_loss: 2.4083 - val_accuracy: 0.6950
# Epoch 25/25
# 2000/2000 [==============================] - 42s 21ms/step - loss: 0.0998 - accuracy: 0.9700 - val_loss: 2.0142 - val_accuracy: 0.6760

# %%
score = model.evaluate(x_test, y_test, verbose=1)
print("Test loss ", score[0])
print("Test acc", score[1])
# Out:
# 1000/1000 [==============================] - 5s 5ms/step
# Test loss  2.014238723754883
# Test acc 0.6759999990463257

# %% [markdown]
# Now use data augmentation tecnhique

# %%
from keras.preprocessing.image import ImageDataGenerator

nb_train_samples = 2000
nb_test_samples = 1000
batch_size = 16
epochs = 25

train_data_dir = './data/train'
test_data_dir = './data/test'

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    horizontal_flip=True,
    fill_mode='nearest' 
    )

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(size,size),
    batch_size=batch_size,
    class_mode="binary",
    shuffle=True
)

test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=(size,size),
    batch_size=batch_size,
    class_mode="binary",
    shuffle=False
)
# Out:
# Found 1998 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# Model remains with same architecture

# %%
model = Sequential()
model.add(Conv2D(32, (3,3), input_shape=(size, size, 3), activation="relu"))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(32, (3,3), activation="relu"))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(64, (3,3), activation="relu"))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(rate=0.5))
model.add(Dense(1, activation="sigmoid"))

model.compile(optimizer='rmsprop', loss="binary_crossentropy", metrics=['accuracy'])

# %%
history = model.fit_generator(train_generator, 
                              steps_per_epoch=nb_train_samples//batch_size,
                              epochs=epochs,
                              validation_data=test_generator,
                              validation_steps=nb_test_samples//batch_size)
# Out:
# Epoch 1/25
# 125/125 [==============================] - 45s 363ms/step - loss: 0.7118 - accuracy: 0.5045 - val_loss: 0.6649 - val_accuracy: 0.4950
# Epoch 2/25
# 125/125 [==============================] - 43s 345ms/step - loss: 0.6987 - accuracy: 0.5125 - val_loss: 0.5376 - val_accuracy: 0.5030
# Epoch 3/25
# 125/125 [==============================] - 43s 347ms/step - loss: 0.6891 - accuracy: 0.5526 - val_loss: 0.5635 - val_accuracy: 0.6179
# Epoch 4/25
# 125/125 [==============================] - 44s 349ms/step - loss: 0.6736 - accuracy: 0.5891 - val_loss: 0.6091 - val_accuracy: 0.6026
# Epoch 5/25
# 125/125 [==============================] - 43s 346ms/step - loss: 0.6706 - accuracy: 0.6076 - val_loss: 0.8366 - val_accuracy: 0.6230
# Epoch 6/25
# 125/125 [==============================] - 44s 349ms/step - loss: 0.6704 - accuracy: 0.5816 - val_loss: 0.6244 - val_accuracy: 0.6392
# Epoch 7/25
# 125/125 [==============================] - 43s 346ms/step - loss: 0.6466 - accuracy: 0.6276 - val_loss: 0.4929 - val_accuracy: 0.5915
# Epoch 8/25
# 125/125 [==============================] - 43s 347ms/step - loss: 0.6595 - accuracy: 0.6211 - val_loss: 0.6388 - val_accuracy: 0.6535
# Epoch 9/25
# 125/125 [==============================] - 43s 344ms/step - loss: 0.6553 - accuracy: 0.6411 - val_loss: 0.4544 - val_accuracy: 0.6738
# Epoch 10/25
# 125/125 [==============================] - 43s 345ms/step - loss: 0.6344 - accuracy: 0.6547 - val_loss: 0.6371 - val_accuracy: 0.6799
# Epoch 11/25
# 125/125 [==============================] - 43s 345ms/step - loss: 0.6309 - accuracy: 0.6507 - val_loss: 0.7896 - val_accuracy: 0.6677
# Epoch 12/25
# 125/125 [==============================] - 43s 347ms/step - loss: 0.6370 - accuracy: 0.6617 - val_loss: 0.6561 - val_accuracy: 0.6829
# Epoch 13/25
# 125/125 [==============================] - 44s 355ms/step - loss: 0.6345 - accuracy: 0.6717 - val_loss: 0.7633 - val_accuracy: 0.7022
# Epoch 14/25
# 125/125 [==============================] - 41s 326ms/step - loss: 0.6240 - accuracy: 0.6617 - val_loss: 0.5149 - val_accuracy: 0.7063
# Epoch 15/25
# 125/125 [==============================] - 41s 325ms/step - loss: 0.6121 - accuracy: 0.6562 - val_loss: 0.4144 - val_accuracy: 0.6352
# Epoch 16/25
# 125/125 [==============================] - 40s 323ms/step - loss: 0.6152 - accuracy: 0.6687 - val_loss: 0.4730 - val_accuracy: 0.7063
# Epoch 17/25
# 125/125 [==============================] - 41s 324ms/step - loss: 0.6067 - accuracy: 0.6912 - val_loss: 0.5091 - val_accuracy: 0.7043
# Epoch 18/25
# 125/125 [==============================] - 41s 329ms/step - loss: 0.5940 - accuracy: 0.6802 - val_loss: 0.3882 - val_accuracy: 0.7083
# Epoch 19/25
# 125/125 [==============================] - 40s 323ms/step - loss: 0.6213 - accuracy: 0.6652 - val_loss: 0.6360 - val_accuracy: 0.7002
# Epoch 20/25
# 125/125 [==============================] - 41s 326ms/step - loss: 0.6160 - accuracy: 0.6747 - val_loss: 0.5119 - val_accuracy: 0.7266
# Epoch 21/25
# 125/125 [==============================] - 41s 325ms/step - loss: 0.6216 - accuracy: 0.6822 - val_loss: 0.6500 - val_accuracy: 0.7165
# Epoch 22/25
# 125/125 [==============================] - 41s 325ms/step - loss: 0.6023 - accuracy: 0.6927 - val_loss: 0.6220 - val_accuracy: 0.7236
# Epoch 23/25
# 125/125 [==============================] - 40s 324ms/step - loss: 0.5952 - accuracy: 0.7042 - val_loss: 0.6711 - val_accuracy: 0.6931
# Epoch 24/25
# 125/125 [==============================] - 41s 325ms/step - loss: 0.6045 - accuracy: 0.6827 - val_loss: 0.3837 - val_accuracy: 0.7144
# Epoch 25/25
# 125/125 [==============================] - 40s 321ms/step - loss: 0.6023 - accuracy: 0.6832 - val_loss: 0.5933 - val_accuracy: 0.7154

# %%
import matplotlib.pyplot as plt

history_dict = history.history

acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(acc_values) + 1)

line1 = plt.plot(epochs, val_acc_values, label='Validation/Test Accuracy')
line2 = plt.plot(epochs, acc_values, label='Training Accuracy')
plt.setp(line1, linewidth=2.0, marker = '+', markersize=10.0)
plt.setp(line2, linewidth=2.0, marker = '4', markersize=10.0)
plt.xlabel('Epochs') 
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Well, +4% of accuracy is not such a big deal, but my goal was just to get along with data augmentations in keras
